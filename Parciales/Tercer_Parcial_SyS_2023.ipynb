# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicoflyy/Senales-y-Sistemas_2023-2/blob/main/Parciales/Tercer_Parcial_SyS_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Solución:**
#
# * **Punto 1.**

# %% [markdown]
# ![P1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![p2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![p3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Simulacion.**
